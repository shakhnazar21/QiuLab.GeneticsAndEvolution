# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("codonaa.csv")

# %%
df
# Out:
#    Codon Amino Acid
# 0    UUU          F
# 1    UUC          F
# 2    UUA          L
# 3    UUG          L
# 4    CUU          L
# ..   ...        ...
# 59   AGG          R
# 60   GGU          G
# 61   GGC          G
# 62   GGA          G
# 63   GGG          G
#
# [64 rows x 2 columns]

# %%
def rnaToProtein(rnaLength, rf, ):
  rna = np.random.choice(["A","C","U","G"],size = rnaLength)
  rna="".join(rna)
  protein = ""
  for j in range(0,rnaLength - 2,3):
    if (rf + j + 3) <= rnaLength:
      codon = rna[rf+j:rf+j+3]
      for i in range(df.shape[0]):
        if df.iloc[i,0] == codon:
          a = df.iloc[i,1]
          protein = "".join([protein, a])
  return(protein)

# %%
rnaToProtein(11,8)
# Out:
# 'R'
